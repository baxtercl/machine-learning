# %% [markdown]
# # Evaluación de asteroides

# %% [markdown]
# ### Importación de datos

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

plt.style.use('ggplot')

# %%
random.seed(1111)
np.random.seed(1111)
pd.set_option("display.max_columns", None)
pd.reset_option("display.max_rows")

# %%
# importar datos
df = pd.read_csv("tarea2Data.csv")

# %%
df.info()
df.describe(include="all")
df.head()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   full_name       100000 non-null  object
#  1   a               100000 non-null  float64
#  2   e               100000 non-null  float64
#  3   G               83 non-null      float64
#  4   i               100000 non-null  float64
#  5   om              100000 non-null  float64
#  6   w               100000 non-null  float64
#  7   q               100000 non-null  float64
#  8   ad              100000 non-null  float64
#  9   per_y           100000 non-null  float64
#  10  data_arc        99902 non-null   float64
#  11  condition_code  100000 non-null  int64
#  12  n_obs_used      100000 non-null  int64
#  13  H               99450 non-null   float64
#  14  extent          11 non-null      object
#  15  albedo          99106 non-null   float64
#  16  rot_per         8102 non-null    float64
#  17  GM              11 non-null      float64
#  18  BV              709 non-null     float64
#  19  UB              682 non-null     float64
#  20  IR              1 non-null       float64
#  21  spec_B          989 non-null     object
#  22  spec_T          690 non-null     object
#  23  neo             100000 non-null  object
#  24  pha             100000 non-null  object
#  25  moid            100000 non-null  float64
#  26  Danger          100000 non-null  bool
# dtypes: bool(1), float64(18), int64(2), object(6)
# memory usage: 19.9+ MB
#          full_name         a         e   G          i          om           w  \
# 99995  (2003 BH74)  2.670063  0.134364 NaN  16.550615  103.041992  353.103112
# 99996  (2000 EV30)  3.003917  0.097908 NaN  10.039414   49.125131  302.969306
# 99997  (2007 TG69)  3.054121  0.045967 NaN   1.787741  222.936419  150.882122
# 99998  (2008 DP26)  3.157728  0.186746 NaN  25.300444  178.902788   97.637852
# 99999  (2000 CV27)  3.187858  0.160119 NaN   0.980044  181.243837  154.724714
#
#               q        ad     per_y  data_arc  condition_code  n_obs_used  \
# 99995  2.311303  3.028823  4.363052    6175.0               0         442
# 99996  2.709811  3.298024  5.206431   13231.0               0        1751
# 99997  2.913732  3.194511  5.337497    6347.0               0         138
# 99998  2.568034  3.747421  5.611387    9350.0               0         146
# 99999  2.677423  3.698293  5.691893   11605.0               0        1322
#
#           H extent  albedo  rot_per  GM  BV  UB  IR spec_B spec_T neo pha  \
# 99995  15.7    NaN   0.109      NaN NaN NaN NaN NaN    NaN    NaN   N   N
# 99996  13.4    NaN   0.256      NaN NaN NaN NaN NaN    NaN    NaN   N   N
# 99997  16.5    NaN   0.023      NaN NaN NaN NaN NaN    NaN    NaN   N   N
# 99998  15.6    NaN   0.033      NaN NaN NaN NaN NaN    NaN    NaN   N   N
# 99999  13.5    NaN   0.070      NaN NaN NaN NaN NaN    NaN    NaN   N   N
#
#           moid  Danger
# 99995  1.32895    True
# 99996  1.72091    True
# 99997  1.91316    True
# 99998  1.69556    True
# 99999  1.66696    True

# %%
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.scatter(x=df.height, y=df.weight, alpha= 0.8)
ax.set_xlabel('Altura')
ax.set_ylabel('Peso');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-f9826e935adf> in <module>
#       1 fig, ax = plt.subplots(1, 1, figsize=(6,4))
# ----> 2 ax.scatter(x=df.height, y=df.weight, alpha= 0.8)
#       3 ax.set_xlabel('Altura')
#       4 ax.set_ylabel('Peso');
#
# ~/.pyenv/versions/3.8.6/envs/venv38/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'height'
